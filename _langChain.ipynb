# %% [markdown]
# <a href="https://colab.research.google.com/github/Metidji/run-llm-free-with-langchain/blob/main/_langChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **How to run a small LLM for free on Colab and integrate it with LangChain**

# %%
#  1. Installation
# !pip install -q langchain langchain_community transformers accelerate bitsandbytes
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 83.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00

# %%
## 2. Imports & Setup
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, pipeline
from langchain_community.llms import HuggingFacePipeline

# %%
## 3. Load the Model
#We use the `chavinlo/alpaca-native` model in 4‑bit mode to save memory and run efficiently:

model_id = "chavinlo/alpaca-native"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    load_in_4bit=True,
    torch_dtype="auto",
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/96.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.
# config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# pytorch_model-00002-of-00003.bin:   0%|          | 0.00/9.89G [00:00<?, ?B/s]
# pytorch_model-00001-of-00003.bin:   0%|          | 0.00/9.88G [00:00<?, ?B/s]
# pytorch_model-00003-of-00003.bin:   0%|          | 0.00/7.18G [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:609: UserWarning: `pad_token_id` should be positive but got -1. This will cause errors when batch generating, if there is padding. Please set `pad_token_id` explicitly as `model.generation_config.pad_token_id=PAD_TOKEN_ID` to avoid errors in generation
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
## 4. Create a Hugging Face Pipeline
#Wrap the model into a text-generation pipeline:

hf_pipeline = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_length=256,
)

llm = HuggingFacePipeline(pipeline=hf_pipeline)
# Out:
# Device set to use cuda:0
# <ipython-input-4-611b100dda9b>:11: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   llm = HuggingFacePipeline(pipeline=hf_pipeline)

# %%
## 5. testing the model
prompt = "Write a short story about a ml and dl with comparason."
response = llm(prompt)

print("📜 Response:\n", response)
# Out:
# 📜 Response:
#  Write a short story about a ml and dl with comparason.
# The story is about a young man who is struggling to find his identity. He is torn between his traditional Indian heritage and his American upbringing. He is trying to find a way to reconcile the two and make it work. He is also dealing with the pressure of his parents’ expectations and his own expectations of himself. The story is told in a very engaging way and it’s easy to relate to the main character’s struggles. I would recommend this story to anyone who is looking for a thought-provoking read.
# This entry was posted in Uncategorized and tagged book review, books, comparison, culture, identity, indian, literature, reading, short story, traditional, young adult on April 29, 2019 by M.S. Forbes.

# %%
## 5. Integrate with LangChain
# You can create a prompt template by defining a string with placeholders
#  and using PromptTemplate.from_template().

from langchain.prompts import PromptTemplate

template = "Write a short story about a {animal} who loves {activity}."
prompt = PromptTemplate.from_template(template)

# %%
#To generate the final prompt string, use the format() method with the appropriate values
# for the placeholders

formatted_prompt = prompt.format(animal="cat", activity="painting")
print(formatted_prompt)
# Out:
# Write a short story about a cat who loves painting.

# %%
#Once you have the formatted prompt, you can pass it to an LLM for processing

response = llm(formatted_prompt)
print(response)
# Out:
# Write a short story about a cat who loves painting. He is an excellent painter and loves to create art. He is always looking for new ideas and materials to use in his art. He is also very creative and loves to experiment with different mediums. He is always eager to learn new techniques and is always looking for ways to improve his art. He is a very hardworking and dedicated artist who loves to create and is always looking for ways to challenge himself. He is a very passionate artist who loves to share his work with others. He is always looking for ways to express himself through his art. He is a very talented and creative painter who loves to create art. He is always eager to learn new techniques and is always looking for ways to improve his art. He is a very passionate artist who loves to share his work with others. He is always looking for ways to express himself through his art. He is a very talented and creative painter who loves to create art. He is always eager to learn new techniques and is always looking for ways to improve his art. He is a very passionate artist who loves to share his work with others. He is always looking for ways to express

# %% [markdown]
# # **Example usage Langchain**
# LangChain supports few-shot learning by allowing you to include examples in your prompt templates. This can help the model understand the desired output format or style

# %%
# take example of translate to see output and compare after Implementing Few-Shot Prompting
response = llm("Translate 'Hello' to French.")
print(response)
# Out:
# Translate 'Hello' to French.
# The French language is a beautiful language with a rich and varied history. It is the sixth-most spoken language in the world, with over 100 million native speakers. It is also the official language of many countries, including France, Belgium, Switzerland, Canada, and Haiti. French is also the language of many classic works of literature, including Les Misérables and The Count of Monte Cristo.
# French is a language of love, with its romantic sound and its poetic nature. It is also a language of culture, with its strong ties to the arts, cuisine, and fashion. Whether you’re looking to learn the language for business or pleasure, French is a great language to learn.
# French is a language of culture, with its strong ties to the arts, cuisine, and fashion. Whether you’re looking to learn the language for business or pleasure, French is a great language to learn.

# %% [markdown]
# **Few-Shot Prompt Templates**
#
# is a technique where you supply the model with a few examples of the desired behavior. This helps the model understand the task better, especially when it's not performing as expected with zero-shot prompts. In LangChain, the FewShotPromptTemplate class facilitates this by allowing you to define:​
# Pinecone
#
# Examples: A list of dictionaries containing input-output pairs.
#
# Example Prompt: A PromptTemplate that formats each example.
#
# Prefix/Suffix: Strings that wrap around the examples, providing context or instructions.

# %%
from langchain.prompts import FewShotPromptTemplate

# 1. Define the Examples
examples = [
    {"input": "Translate 'Thank you' to French.", "output": "merci"},
    {"input": "Translate 'Goodbye' to French.", "output": "Au revoir"}
]

# 2. Create the Example Prompt Template
example_prompt = PromptTemplate.from_template("Input: {input}\nOutput: {output}")

# 3. Construct the Few-Shot Prompt Template
few_shot_prompt = FewShotPromptTemplate(
    examples=examples,  # The list of example translations
    example_prompt=example_prompt,  # How each example is formatted
    prefix="Translate the following sentences to French:",  # Instruction before examples
    suffix="Input: Translate '{sentence}' to French.\nOutput:",  # Prompt for the new input
    input_variables=["sentence"]  # Variable to be filled with the new sentence
)

# 4. Format the Prompt with New Input
formatted_prompt = few_shot_prompt.format(sentence="Good morning")

response = llm(formatted_prompt)
print(response)
# Out:
# Translate the following sentences to French:
#
# Input: Translate 'Thank you' to French.
# Output: merci
#
# Input: Translate 'Goodbye' to French.
# Output: Au revoir
#
# Input:Translate 'Good morning' to French.
# Output: Bonjour
